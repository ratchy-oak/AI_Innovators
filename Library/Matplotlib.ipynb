# %% [markdown]
# # Mathplotlib

# %% [markdown]
# Ref: https://matplotlib.org/stable/tutorials/index.html
#
#
# Cheatsheets: https://matplotlib.org/cheatsheets/cheatsheets.pdf

# %%
# !pip install matplotlib

# %%
import matplotlib
matplotlib.__version__
# Out:
# '3.7.1'

# %%
import matplotlib.pyplot as plt
import numpy as np
fig, ax = plt.subplots()             # Create a figure containing a single Axes.
x = [10, 20, 30, 40]
y = [1, 4, 2, 3]
ax.plot(x, y)                        # Plot some data on the Axes.
plt.show()                           # Show the figure.

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 2*np.pi, 200) # start, stop, no of array
y = np.sin(x)

fig, ax = plt.subplots()
ax.plot(x, y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
fig, ax = plt.subplots()             # Create a figure containing a single Axes.

#data
X = np.linspace(0, 10, 100)
Y = np.random.randint(0, 10, 100)

#plot
ax.plot(X, Y)                        # Plot some data on the Axes.
plt.show()                           # Show the figure.

# %%
import matplotlib.pyplot as plt
import numpy as np

fig, ax = plt.subplots(figsize=(8, 4))             # Create a figure containing a single Axes.

#data
X = np.linspace(0, 10, 100)
Y = np.random.randint(0, 10, 100)

#plot
ax.plot(X, Y, label='linear')                        # Plot some data on the Axes.

#label
ax.set_xlabel('x label')  # Add an x-label to the Axes.
ax.set_ylabel('y label')  # Add a y-label to the Axes.

#title
ax.set_title("Simple Plot")  # Add a title to the Axes.

plt.show()                                             # Show the figure.

# %%
import matplotlib.pyplot as plt
import numpy as np

#data
x = np.linspace(0, 2, 100)
Y = np.random.randint(0, 10, 100)

#plot
plt.figure(figsize=(8, 4), layout='constrained')

#add line
plt.plot(x, x, label='linear')
plt.plot(x, x**2, label='quadratic')
plt.plot(x, x**3, label='cubic')

#add label
plt.xlabel('x label')
plt.ylabel('y label')

#add title
plt.title("Simple Plot")

#add legend
plt.legend()

# %%
# line style

import matplotlib.pyplot as plt
import numpy as np

fig, ax = plt.subplots(figsize=(5, 2.7))

x = np.arange(len(data1))

ax.plot(x, np.cumsum(data1), color='blue', linewidth=1, linestyle='--')

l, = ax.plot(x, np.cumsum(data2), color='orange', linewidth=2)

l.set_linestyle(':')

ax.plot(x, np.cumsum(data3), color='red', linewidth=3, linestyle='dotted')

# %%
# color
import matplotlib.pyplot as plt
import numpy as np

fig, ax = plt.subplots(figsize=(5, 2.7))

ax.scatter(data1, data2, s=50, facecolor='C0', edgecolor='k')
